# %%
import datetime
import numpy as np
import pandas as pd
import yfinance as yf
import warnings
import scipy.stats as stats
import matplotlib.pyplot as plt
from scipy.stats import shapiro

# %%
def day_price_ret(ticker_symbol,s_date,e_date):
    stock_symbol = ticker_symbol

    stock_data = yf.download(stock_symbol, start=s_date, end=e_date)
    stock_data = stock_data.set_index(pd.to_datetime(stock_data.index))

    weekly_returns = stock_data['Adj Close'].pct_change().dropna()

    return pd.DataFrame(weekly_returns)

# %%
warnings.filterwarnings('ignore')
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# %%
stock_list = ['^KS11','^KQ11','034730.ks' , '023530.ks','267250.ks','006730.kq','086790.ks','395400.ks','330590.ks','357120.ks','404990.ks','417310.ks']
stock_name = ['코스피','코스닥','SK㈜','롯데쇼핑','HD현대','서부티앤디','하나금융지주','SK리츠','롯데리츠','코람코라이프인프라리츠','신한서부티앤디리츠','코람코더원리츠']

# %%
s_date = datetime.datetime(2022,4,1)
e_date = datetime.datetime(2024,4,1)

fig = plt.figure(figsize=(20,15))
for i in range(len(stock_list)):
    ax = fig.add_subplot(3,4,i+1)
    df = day_price_ret(stock_list[i],s_date,e_date)['Adj Close']
    stats.probplot(df, dist=stats.norm, plot=ax)
    ax.set_title(stock_name[i])
    shapiro_test = stats.shapiro(df)
    print(f"{stock_name[i]}의 정규성 검정 결과: {shapiro_test[1] :.4f}")
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# 코스피의 정규성 검정 결과: 0.0001
# 코스닥의 정규성 검정 결과: 0.0000
# SK㈜의 정규성 검정 결과: 0.0000
# 롯데쇼핑의 정규성 검정 결과: 0.0000
# HD현대의 정규성 검정 결과: 0.0000
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# 서부티앤디의 정규성 검정 결과: 0.0000
# 하나금융지주의 정규성 검정 결과: 0.0000
# SK리츠의 정규성 검정 결과: 0.0000
# 롯데리츠의 정규성 검정 결과: 0.0000
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# 코람코라이프인프라리츠의 정규성 검정 결과: 0.0000
# 신한서부티앤디리츠의 정규성 검정 결과: 0.0000
# 코람코더원리츠의 정규성 검정 결과: 0.0000

# %%
s_date = datetime.datetime(2022,7,1)
e_date = datetime.datetime(2022,12,31)

fig = plt.figure(figsize=(20,15))
for i in range(len(stock_list)):
    ax = fig.add_subplot(3,4,i+1)
    df = day_price_ret(stock_list[i],s_date,e_date)['Adj Close']
    stats.probplot(df, dist=stats.norm, plot=ax)
    ax.set_title(stock_name[i])
    shapiro_test = stats.shapiro(df)
    print(f"{stock_name[i]}의 정규성 검정 결과: {shapiro_test[1] :.4f}")
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# 코스피의 정규성 검정 결과: 0.9009
# 코스닥의 정규성 검정 결과: 0.8229
# [*********************100%%**********************]  1 of 1 completed
# SK㈜의 정규성 검정 결과: 0.6400
# [*********************100%%**********************]  1 of 1 completed
# 롯데쇼핑의 정규성 검정 결과: 0.1051
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# HD현대의 정규성 검정 결과: 0.0007
# 서부티앤디의 정규성 검정 결과: 0.5563
# [*********************100%%**********************]  1 of 1 completed
# 하나금융지주의 정규성 검정 결과: 0.3261
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# SK리츠의 정규성 검정 결과: 0.0028
# 롯데리츠의 정규성 검정 결과: 0.0000
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# 코람코라이프인프라리츠의 정규성 검정 결과: 0.7192
# 신한서부티앤디리츠의 정규성 검정 결과: 0.0000
# [*********************100%%**********************]  1 of 1 completed
# 코람코더원리츠의 정규성 검정 결과: 0.0000

# %%
s_date = datetime.datetime(2023,2,1)
e_date = datetime.datetime(2023,7,31)

fig = plt.figure(figsize=(20,15))
for i in range(len(stock_list)):
    ax = fig.add_subplot(3,4,i+1)
    df = day_price_ret(stock_list[i],s_date,e_date)['Adj Close']
    stats.probplot(df, dist=stats.norm, plot=ax)
    ax.set_title(stock_name[i])
    shapiro_test = stats.shapiro(df)
    print(f"{stock_name[i]}의 정규성 검정 결과: {shapiro_test[1] :.4f}")
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# 코스피의 정규성 검정 결과: 0.6047
# 코스닥의 정규성 검정 결과: 0.0676
# [*********************100%%**********************]  1 of 1 completed
# SK㈜의 정규성 검정 결과: 0.2341
# [*********************100%%**********************]  1 of 1 completed
# 롯데쇼핑의 정규성 검정 결과: 0.0219
# [*********************100%%**********************]  1 of 1 completed
# HD현대의 정규성 검정 결과: 0.0009
# [*********************100%%**********************]  1 of 1 completed
# 서부티앤디의 정규성 검정 결과: 0.0002
# [*********************100%%**********************]  1 of 1 completed
# 하나금융지주의 정규성 검정 결과: 0.3550
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# SK리츠의 정규성 검정 결과: 0.0102
# [*********************100%%**********************]  1 of 1 completed
# 롯데리츠의 정규성 검정 결과: 0.0782
# 코람코라이프인프라리츠의 정규성 검정 결과: 0.5487
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# 신한서부티앤디리츠의 정규성 검정 결과: 0.0017
# 코람코더원리츠의 정규성 검정 결과: 0.0007
